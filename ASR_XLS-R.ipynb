# %% [markdown]
# ## Import all the essential libraries

# %%
# !pip install nltk
# !pip install torch
# !pip install torchaudio
# !pip install librosa
# !pip install soundfile
# !pip install scipy
# !pip install IPython
# !pip install transformers
# !pip install huggingface_hub
# Out:
# Requirement already satisfied: torch in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (1.12.1)
# Requirement already satisfied: typing-extensions in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from torch) (4.3.0)
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: torchaudio in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (0.12.1)
# Requirement already satisfied: torch==1.12.1 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from torchaudio) (1.12.1)
# Requirement already satisfied: typing-extensions in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from torch==1.12.1->torchaudio) (4.3.0)
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting librosa
#   Downloading librosa-0.9.2-py3-none-any.whl (214 kB)
#      ------------------------------------ 214.3/214.3 kB 726.3 kB/s eta 0:00:00
# Requirement already satisfied: joblib>=0.14 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from librosa) (1.1.0)
# Requirement already satisfied: decorator>=4.0.10 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from librosa) (5.1.1)
# Collecting pooch>=1.0
#   Downloading pooch-1.6.0-py3-none-any.whl (56 kB)
#      -------------------------------------- 56.3/56.3 kB 742.2 kB/s eta 0:00:00
# Collecting resampy>=0.2.2
#   Downloading resampy-0.4.0-py3-none-any.whl (3.1 MB)
#      ---------------------------------------- 3.1/3.1 MB 1.1 MB/s eta 0:00:00
# Collecting numba>=0.45.1
#   Downloading numba-0.56.0-cp39-cp39-win_amd64.whl (2.5 MB)
#      ---------------------------------------- 2.5/2.5 MB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.2.0 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from librosa) (1.8.1)
# Requirement already satisfied: scikit-learn>=0.19.1 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from librosa) (1.1.1)
# Collecting audioread>=2.1.9
#   Downloading audioread-3.0.0.tar.gz (377 kB)
#      -------------------------------------- 377.0/377.0 kB 1.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: soundfile>=0.10.2 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from librosa) (0.10.3.post1)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from librosa) (1.23.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from librosa) (21.3)
# Collecting numpy>=1.17.0
#   Downloading numpy-1.22.4-cp39-cp39-win_amd64.whl (14.7 MB)
#      ---------------------------------------- 14.7/14.7 MB 1.4 MB/s eta 0:00:00
# Collecting llvmlite<0.40,>=0.39.0dev0
#   Downloading llvmlite-0.39.0-cp39-cp39-win_amd64.whl (23.2 MB)
#      ---------------------------------------- 23.2/23.2 MB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from numba>=0.45.1->librosa) (49.2.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from packaging>=20.0->librosa) (3.0.9)
# Collecting appdirs>=1.3.0
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: requests>=2.19.0 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from pooch>=1.0->librosa) (2.28.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from scikit-learn>=0.19.1->librosa) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from soundfile>=0.10.2->librosa) (1.15.1)
# Requirement already satisfied: pycparser in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.21)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2022.6.15)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.1.0)
# Using legacy 'setup.py install' for audioread, since package 'wheel' is not installed.
# Installing collected packages: appdirs, numpy, llvmlite, audioread, pooch, numba, resampy, librosa
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.0
#     Uninstalling numpy-1.23.0:
#       Successfully uninstalled numpy-1.23.0
#   Running setup.py install for audioread: started
#   Running setup.py install for audioread: finished with status 'done'
# Successfully installed appdirs-1.4.4 audioread-3.0.0 librosa-0.9.2 llvmlite-0.39.0 numba-0.56.0 numpy-1.22.4 pooch-1.6.0 resampy-0.4.0
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (1.22.4)
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: soundfile in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (0.10.3.post1)
# Requirement already satisfied: cffi>=1.0 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from soundfile) (1.15.1)
# Requirement already satisfied: pycparser in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from cffi>=1.0->soundfile) (2.21)
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: scipy in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (1.8.1)
# Requirement already satisfied: numpy<1.25.0,>=1.17.3 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from scipy) (1.22.4)
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: IPython in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (8.4.0)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from IPython) (2.12.0)
# Requirement already satisfied: backcall in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from IPython) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from IPython) (49.2.1)
# Requirement already satisfied: traitlets>=5 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from IPython) (5.3.0)
# Requirement already satisfied: colorama in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from IPython) (0.4.5)
# Requirement already satisfied: stack-data in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from IPython) (0.3.0)
# Requirement already satisfied: pickleshare in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from IPython) (0.7.5)
# Requirement already satisfied: matplotlib-inline in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from IPython) (0.1.3)
# Requirement already satisfied: jedi>=0.16 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from IPython) (0.18.1)
# Requirement already satisfied: decorator in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from IPython) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from IPython) (3.0.30)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from jedi>=0.16->IPython) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython) (0.2.5)
# Requirement already satisfied: asttokens in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from stack-data->IPython) (2.0.5)
# Requirement already satisfied: executing in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from stack-data->IPython) (0.8.3)
# Requirement already satisfied: pure-eval in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from stack-data->IPython) (0.2.2)
# Requirement already satisfied: six in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from asttokens->stack-data->IPython) (1.16.0)
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: transformers in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (4.21.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from transformers) (0.9.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from transformers) (2022.8.17)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from transformers) (0.12.1)
# Requirement already satisfied: requests in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from transformers) (2.28.1)
# Requirement already satisfied: tqdm>=4.27 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from transformers) (4.64.0)
# Requirement already satisfied: filelock in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from transformers) (3.8.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from transformers) (21.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from transformers) (1.22.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: colorama in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from tqdm>=4.27->transformers) (0.4.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from requests->transformers) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from requests->transformers) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from requests->transformers) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from requests->transformers) (2.1.0)
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: huggingface_hub in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (0.9.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from huggingface_hub) (4.3.0)
# Requirement already satisfied: filelock in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from huggingface_hub) (3.8.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from huggingface_hub) (6.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from huggingface_hub) (21.3)
# Requirement already satisfied: tqdm in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from huggingface_hub) (4.64.0)
# Requirement already satisfied: requests in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from huggingface_hub) (2.28.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from packaging>=20.9->huggingface_hub) (3.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from requests->huggingface_hub) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from requests->huggingface_hub) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from requests->huggingface_hub) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from requests->huggingface_hub) (2.1.0)
# Requirement already satisfied: colorama in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from tqdm->huggingface_hub) (0.4.5)
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# transformers and torch
import torch
import librosa
import numpy as np
import soundfile as sf
from scipy.io import wavfile
from IPython.display import Audio
from transformers import Wav2Vec2ForCTC, Wav2Vec2Tokenizer

#nltk and sklearn
from nltk.tag.perceptron import PerceptronTagger
from nltk.stem import WordNetLemmatizer
from sklearn import decomposition
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from stemming.porter2 import stem
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.cluster import KMeans
from scipy.sparse import hstack

# %% [markdown]
# ## Load tokenizer and model

# %%
tokenizer = Wav2Vec2Tokenizer.from_pretrained("facebook/wav2vec2-base-960h")
model = Wav2Vec2ForCTC.from_pretrained("facebook/wav2vec2-base-960h")
# Out:
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'Wav2Vec2CTCTokenizer'.
# The class this function is called from is 'Wav2Vec2Tokenizer'.
# c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages\transformers\models\wav2vec2\tokenization_wav2vec2.py:754: FutureWarning: The class `Wav2Vec2Tokenizer` is deprecated and will be removed in version 5 of Transformers. Please use `Wav2Vec2Processor` or `Wav2Vec2CTCTokenizer` instead.
#   warnings.warn(
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-base-960h and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# ## Check audio samples

# %%
file_name_0 = 'voc-audio-0.wav'
Audio(file_name_0)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
file_name_1 = 'voc-audio-1.wav'
Audio(file_name_1)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
file_name_2 = 'voc-audio-2.wav'
Audio(file_name_2)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import os
import wave

path = "C:\\Users\\Theodore\\Downloads\\wave2vec-speech-to-text"
directory = os.fsencode(path)
  
# Function to read audio files
def read_text_file(file_path):
    with open(file_path, 'r') as f:
        print(f.read())
        
def create_audio_list(directory):
    """
    This function will take a directory containing the audio files (in wave format) 
    and return an list of the audio file names as strings.
    
    Args:
         path (str): an encoded path of the directory containing the audio files
    Returns:
        list: a list of strings with names of the 
    """
    audiolist = []
    for file in os.listdir(directory):
        filename = os.fsdecode(file)
        if filename.endswith(".wav"): # Check whether file is in wav format or not
            audiolist.append(f"{filename}")
    return audiolist


def get_audiofile_metadata(list_of_audio_files):
    """"
    Function that takes a list of audio files as input and prints out metadata about each file. This includes sampling rate (Hz), length, number of channels (int), sample width (bytes)
    
    Args:
        list: an encoded path of the directory containing the audio files.
    Returns:
        textfile: a text file with containing metadata information about each audio file
    """
    for f in list_of_audio_files:
        with wave.open(f) as w:
            framerate = w.getframerate()
            frames = w.getnframes()
            channels = w.getnchannels()
            width = w.getsampwidth()
            print('\n')
            print('\t','%'*25, f"{f}", '%'*25)
            print('sampling rate:', framerate, 'Hz')
            print('length:', frames, 'samples')
            print('channels:', channels)
            print('sample width:', width, 'bytes')

            data = w.readframes(frames)

def get_transcriptions(audio_list):
    """
    
    """
    transcriptions = []
    for voicenote in audio_list:
        data = wavfile.read(voicenote)
        framerate = data[0]
        sounddata = data[1]
        time = np.arange(0,len(sounddata))/framerate
        input_audio, _ = librosa.load(voicenote, sr=16000)
        
        input_values = tokenizer(input_audio, return_tensors="pt").input_values
        logits = model(input_values).logits
        predicted_ids = torch.argmax(logits, dim=-1)

        transcription = tokenizer.batch_decode(predicted_ids)[0]
        transcriptions.append(transcription)
        with open('data.txt', 'w') as f:
            for line in transcriptions:
                f.write(line)
                f.write('\n')
    return transcriptions

# %time get_transcriptions(audiolist)

def readFile(fileName):
    """
    This function will read the text files passed & return the list
    """
    fileObj = open(fileName, "r") #opens the file in read mode
    words = fileObj.read().splitlines() #puts the file into a list
    fileObj.close()
    return words
data = readFile('data.txt')
# Out:
# ['voc-audio-0.wav',
#  'voc-audio-1.wav',
#  'voc-audio-10.wav',
#  'voc-audio-100.wav',
#  'voc-audio-101.wav',
#  'voc-audio-102.wav',
#  'voc-audio-103.wav',
#  'voc-audio-104.wav',
#  'voc-audio-105.wav',
#  'voc-audio-106.wav',
#  'voc-audio-107.wav',
#  'voc-audio-108.wav',
#  'voc-audio-109.wav',
#  'voc-audio-11.wav',
#  'voc-audio-110.wav',
#  'voc-audio-111.wav',
#  'voc-audio-112.wav',
#  'voc-audio-113.wav',
#  'voc-audio-114.wav',
#  'voc-audio-115.wav',
#  'voc-audio-116.wav',
#  'voc-audio-117.wav',
#  'voc-audio-118.wav',
#  'voc-audio-119.wav',
#  'voc-audio-12.wav',
#  'voc-audio-120.wav',
#  'voc-audio-121.wav',
#  'voc-audio-122.wav',
#  'voc-audio-123.wav',
#  'voc-audio-124.wav',
#  'voc-audio-125.wav',
#  'voc-audio-126.wav',
#  'voc-audio-127.wav',
#  'voc-audio-128.wav',
#  'voc-audio-129.wav',
#  'voc-audio-13.wav',
#  'voc-audio-130.wav',
#  'voc-audio-131.wav',
#  'voc-audio-132.wav',
#  'voc-audio-133.wav',
#  'voc-audio-134.wav',
#  'voc-audio-135.wav',
#  'voc-audio-136.wav',
#  'voc-audio-137.wav',
#  'voc-audio-138.wav',
#  'voc-audio-139.wav',
#  'voc-audio-14.wav',
#  'voc-audio-140.wav',
#  'voc-audio-141.wav',
#  'voc-audio-142.wav',
#  'voc-audio-143.wav',
#  'voc-audio-144.wav',
#  'voc-audio-145.wav',
#  'voc-audio-146.wav',
#  'voc-audio-147.wav',
#  'voc-audio-148.wav',
#  'voc-audio-149.wav',
#  'voc-audio-15.wav',
#  'voc-audio-150.wav',
#  'voc-audio-151.wav',
#  'voc-audio-152.wav',
#  'voc-audio-153.wav',
#  'voc-audio-154.wav',
#  'voc-audio-155.wav',
#  'voc-audio-156.wav',
#  'voc-audio-157.wav',
#  'voc-audio-158.wav',
#  'voc-audio-159.wav',
#  'voc-audio-16.wav',
#  'voc-audio-160.wav',
#  'voc-audio-17.wav',
#  'voc-audio-18.wav',
#  'voc-audio-19.wav',
#  'voc-audio-2.wav',
#  'voc-audio-20.wav',
#  'voc-audio-21.wav',
#  'voc-audio-22.wav',
#  'voc-audio-23.wav',
#  'voc-audio-24.wav',
#  'voc-audio-25.wav',
#  'voc-audio-26.wav',
#  'voc-audio-27.wav',
#  'voc-audio-28.wav',
#  'voc-audio-29.wav',
#  'voc-audio-3.wav',
#  'voc-audio-30.wav',
#  'voc-audio-31.wav',
#  'voc-audio-32.wav',
#  'voc-audio-33.wav',
#  'voc-audio-34.wav',
#  'voc-audio-35.wav',
#  'voc-audio-36.wav',
#  'voc-audio-37.wav',
#  'voc-audio-38.wav',
#  'voc-audio-39.wav',
#  'voc-audio-4.wav',
#  'voc-audio-40.wav',
#  'voc-audio-41.wav',
#  'voc-audio-42.wav',
#  'voc-audio-43.wav',
#  'voc-audio-44.wav',
#  'voc-audio-45.wav',
#  'voc-audio-46.wav',
#  'voc-audio-47.wav',
#  'voc-audio-48.wav',
#  'voc-audio-49.wav',
#  'voc-audio-5.wav',
#  'voc-audio-50.wav',
#  'voc-audio-51.wav',
#  'voc-audio-52.wav',
#  'voc-audio-53.wav',
#  'voc-audio-54.wav',
#  'voc-audio-55.wav',
#  'voc-audio-56.wav',
#  'voc-audio-57.wav',
#  'voc-audio-58.wav',
#  'voc-audio-59.wav',
#  'voc-audio-6.wav',
#  'voc-audio-60.wav',
#  'voc-audio-61.wav',
#  'voc-audio-62.wav',
#  'voc-audio-63.wav',
#  'voc-audio-64.wav',
#  'voc-audio-65.wav',
#  'voc-audio-66.wav',
#  'voc-audio-67.wav',
#  'voc-audio-68.wav',
#  'voc-audio-69.wav',
#  'voc-audio-7.wav',
#  'voc-audio-70.wav',
#  'voc-audio-71.wav',
#  'voc-audio-72.wav',
#  'voc-audio-73.wav',
#  'voc-audio-74.wav',
#  'voc-audio-75.wav',
#  'voc-audio-76.wav',
#  'voc-audio-77.wav',
#  'voc-audio-78.wav',
#  'voc-audio-79.wav',
#  'voc-audio-8.wav',
#  'voc-audio-80.wav',
#  'voc-audio-81.wav',
#  'voc-audio-82.wav',
#  'voc-audio-83.wav',
#  'voc-audio-84.wav',
#  'voc-audio-85.wav',
#  'voc-audio-86.wav',
#  'voc-audio-87.wav',
#  'voc-audio-88.wav',
#  'voc-audio-89.wav',
#  'voc-audio-90.wav',
#  'voc-audio-91.wav',
#  'voc-audio-92.wav',
#  'voc-audio-93.wav',
#  'voc-audio-94.wav',
#  'voc-audio-95.wav',
#  'voc-audio-96.wav',
#  'voc-audio-97.wav',
#  'voc-audio-98.wav',
#  'voc-audio-99.wav']

# %%
import wave

def get_audiofile_metadata(list_of_audio_files):
    """"
    Function that takes a list of audio files as input and prints out metadata about each file. This includes sampling rate (Hz), length, number of channels (int), sample width (bytes)
    
    Args:
        list: an encoded path of the directory containing the audio files.
    Returns:
        textfile: a text file with containing metadata information about each audio file
    """
    for f in list_of_audio_files:
        with wave.open(f) as w:
            framerate = w.getframerate()
            frames = w.getnframes()
            channels = w.getnchannels()
            width = w.getsampwidth()
            print('\n')
            print('\t','%'*25, f"{f}", '%'*25)
            print('sampling rate:', framerate, 'Hz')
            print('length:', frames, 'samples')
            print('channels:', channels)
            print('sample width:', width, 'bytes')

            data = w.readframes(frames)
            
get_audiofile_metadata(audiolist)
# Out:
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-0.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 61116 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-1.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 39564 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-10.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 98094 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-100.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 197738 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-101.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 207773 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-102.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 45735 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-103.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 116352 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-104.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 44963 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-105.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 202176 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-106.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 59956 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-107.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 54441 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-108.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 82659 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-109.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 108456 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-11.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 63936 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-110.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 202752 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-111.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 105697 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-112.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 91008 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-113.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 49921 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-114.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 93312 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-115.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 142300 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-116.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 55765 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-117.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 39672 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-118.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 94678 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-119.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 95465 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-12.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 42431 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-120.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 223488 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-121.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 37798 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-122.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 53234 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-123.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 54444 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-124.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 68444 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-125.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 126787 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-126.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 63360 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-127.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 74304 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-128.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 113419 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-129.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 92736 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-13.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 45845 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-130.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 67968 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-131.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 73842 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-132.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 49703 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-133.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 70981 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-134.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 66123 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-135.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 47611 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-136.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 52462 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-137.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 78912 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-138.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 64512 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-139.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 147275 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-14.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 40995 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-140.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 66351 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-141.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 64512 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-142.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 70848 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-143.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 77760 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-144.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 69120 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-145.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 69322 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-146.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 153216 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-147.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 76701 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-148.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 65245 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-149.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 54554 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-15.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 62052 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-150.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 58176 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-151.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 53467 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-152.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 77760 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-153.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 51244 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-154.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 48051 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-155.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 50585 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-156.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 74880 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-157.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 72576 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-158.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 99072 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-159.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 57973 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-16.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 53568 samples
# channels: 1
# sample width: 2 bytes
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-160.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 59403 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-17.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 116871 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-18.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 52792 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-19.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 110592 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-2.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 92363 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-20.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 130176 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-21.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 56535 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-22.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 57088 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-23.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 87497 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-24.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 46649 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-25.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 113472 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-26.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 80784 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-27.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 164160 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-28.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 50803 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-29.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 39343 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-3.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 59328 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-30.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 43088 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-31.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 87935 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-32.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 49154 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-33.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 141120 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-34.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 52240 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-35.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 56646 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-36.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 103104 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-37.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 54844 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-38.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 102179 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-39.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 68968 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-4.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 65244 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-40.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 292608 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-41.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 60504 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-42.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 133917 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-43.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 45426 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-44.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 111168 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-45.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 63811 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-46.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 110592 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-47.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 38805 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-48.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 167760 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-49.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 44953 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-5.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 43749 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-50.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 126823 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-51.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 163575 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-52.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 52451 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-53.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 74614 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-54.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 176030 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-55.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 85824 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-56.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 207656 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-57.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 134784 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-58.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 84096 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-59.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 218902 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-6.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 84869 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-60.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 63811 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-61.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 102174 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-62.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 45504 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-63.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 134018 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-64.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 61860 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-65.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 58752 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-66.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 124088 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-67.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 101737 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-68.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 70848 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-69.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 71424 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-7.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 42096 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-70.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 63292 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-71.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 48821 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-72.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 50287 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-73.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 65664 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-74.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 85824 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-75.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 69120 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-76.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 43307 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-77.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 75605 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-78.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 125568 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-79.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 136512 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-8.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 78912 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-80.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 86976 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-81.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 65796 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-82.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 51612 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-83.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 86400 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-84.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 81919 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-85.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 51939 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-86.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 44192 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-87.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 66711 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-88.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 84096 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-89.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 69689 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-90.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 96808 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-91.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 76603 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-92.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 70095 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-93.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 50034 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-94.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 49045 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-95.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 132480 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-96.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 24000 Hz
# length: 76032 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-97.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 228266 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-98.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 56758 samples
# channels: 1
# sample width: 2 bytes
#
#
# 	 %%%%%%%%%%%%%%%%%%%%%%%%% voc-audio-99.wav %%%%%%%%%%%%%%%%%%%%%%%%%
# sampling rate: 22050 Hz
# length: 51687 samples
# channels: 1
# sample width: 2 bytes

# %% [markdown]
# ## Adjust sample rate and Generate transcriptions

# %%
def get_transcriptions(audio_list):
    """
    
    """
    transcriptions = []
    for voicenote in audio_list:
        data = wavfile.read(voicenote)
        framerate = data[0]
        sounddata = data[1]
        time = np.arange(0,len(sounddata))/framerate
        input_audio, _ = librosa.load(voicenote, sr=16000)
        
        input_values = tokenizer(input_audio, return_tensors="pt").input_values
        logits = model(input_values).logits
        predicted_ids = torch.argmax(logits, dim=-1)

        transcription = tokenizer.batch_decode(predicted_ids)[0]
        transcriptions.append(transcription)
        with open('data.txt', 'w') as f:
            for line in transcriptions:
                f.write(line)
                f.write('\n')
    return transcriptions

# %%
import time

print('\t','%'*25, 'Transcription started', '%'*25)
# %time get_transcriptions(audiolist)
# Out:
# CPU times: total: 9min 36s
# Wall time: 6min 42s
# ['WHAT IS THE TRACKING NUMBER FOR MY CART THAT WAS MAILED',
#  'HOW DO I TRACK MY CARD',
#  "I'M STARTING TO THINK MY CARD IS LOST BECAUSE IT STILL HASN'T ARRIVED CAN YOU HELP",
#  "I RECENTLY GOT A NEW PLACE WHILE I'M STAYING ABROAD AND HAVE BEEN USING THIS ACCOUNT TO MANAGE PAYMENTS BUT SUDDENLY I AM SEEING FEES INCREASE WHERE ARE THESE ADDITIONAL FEES COMING FROM",
#  'I PURCHASED SOME MAKE UP THROUGH A SIGHT IN CHINA AND I WAS UNDER THE IMPRESSION THAT WHEN I MAY TRANSFERS THERE IS NO FEE WHY AM I SEEING THIS FENOW I AM NOT HAPPY ABOUT THIS AT ALL',
#  "I'M NOT PAYING THIS TRANSFER FEE",
#  'I THOUGHT TRANSFERS WERE FREE WHY WAS I CHARGE TO FEE',
#  'WHAT IS THE TRANSFER F E CHARGE',
#  'WHY DID I GET CHARGED FOR SOMETHING I BOUGHT ON LINE EVEN THOUGH IT WAS INTERNATIONAL I THOUGHT IT WOULD BE COVERED',
#  "MY TRANSFER TO BENEFICIARY DIDN'T GO THROUGH",
#  "WHY CAN'T I TRANSFER TO A BENEFICIARY",
#  'WHY DID I RECEIVE AN ERROR MESSAGE SAYING THAT MY TRANSFER WAS NOT POSSIBLE',
#  "I'VE TROD NUMEROUS TIMES TO SUBMIT A TRANSFER OF FUNDS WHY ISN'T IT GOING THROUGH",
#  'MY CARD HAS NOT ARRIVED YET',
#  "I TRIED TO TRANSFER MONEY BUT IT SAID IT WASN'T POSSIBLE I'VE DONE THIS BEFORE AND IT WORKED WHY ISN'T IT WORKING NOW",
#  "I HAVE A CRIPTO CURRENCY EXCHANGE THAT WON'T GO THROUGH PLEASE HELP ME PROCESS IT",
#  "WHAT'S THE DEAL WITH NO CRYPTO CURRENCY ON YOUR RAP",
#  "I COULDN'T DO A TRANSFER TO AN ACCOUNT",
#  'I WAS UNABLE TO MAKE A TRANSFER TO ANOTHER ACCOUNT',
#  "WHY ISN'T MY TRANSFER GOING THROUGH I GET A MESSAGE SAYING IT'S NOT POSSIBLE I'VE HAD NO ISSUES IN THE PAST",
#  "WHY ISN'T MY ACCOUNT ALLOWING TRANSFERS",
#  'I HAD A TRANSFER BLOCKED',
#  "WHY ISN'T MY TRANSFER NOT GOING THROUGH I KEEP GETTING AN ARROR MESSAGE",
#  "I WANT TO BUY CRIPTO CURRENCY BUT YOUR AP DOESN'T LET ME WHY",
#  'STILL WAITING ON MY NEW CARD',
#  'WHY DID I GET A MESSAGE SAYING THAT MY TRANSFER IS NOT POSSIBLE I HAVE DONE THIS BEFORE NO PROBLEM PLEASE FIX',
#  'I NEED TO CHANGE MY PIN',
#  'I NEED A NEW PIN HOW DO I GO ABOUT THAT',
#  'DO CASH MACHINES LET ME CHANGE MY PIN',
#  'WHAT KIND OF CASH MACHINES WOULD ALLOW ME TO CHANGE MY PIN',
#  "I DESPERATELY NEED TO CHANGE MY PIN BUT I'M OVERSEEZ ON VACATION RIGHT NOW HOW CAN I DO THIS",
#  'MY NEW PIN NEEDS TO BE SET',
#  'IN WHAT AH T M CAN I CHANGE MY PIN',
#  'I AM TRAVELLING FOR TWO MORE WEEKS BUT REALLY NEED TO CHANGE MY PINA ES APING WHAT DO I DO',
#  'IF I AM OVERSEAS HOW DO I CHANGE MY PIN',
#  'IS THEIR TRACKING INFO AVAILABLE',
#  'MAY I RECEIVE A DIFFERENT CARD PEN',
#  'PLEASE TELL ME WHICH CASH MACHINES WILL ALLOW ME TO CHANGE MY PIN',
#  'CAN I CHANGE MY PIN AT THE AT M',
#  'THERE MUST BE AN ISSUE WHY HAS MY CARD BEEN CANCELLED',
#  'WHAT DO I DO IF IT SAYS MY CARD PAYMENT HAS BEEN KENCELLED',
#  'WHY WAS MY CARD PAYMENT KENCELLED',
#  'I THINK MY CARD PAYMENT HAS BEEN STOPPED',
#  'WHY HAS MY CARD PAYMENT BEEN CANSELLED',
#  'WHY WAS MY PAYMENT REVERSED',
#  'MY CARD IS BEING DECLINED FOR A PURCHASE I BOUGHT ITEMS BEFORE AND THE CARD WORKED DO YOU KNOW WHAT THE PROBLEM IS',
#  'I HAVE NOT RECEIVED MY CARD',
#  'WHAT HAPPENS TO THE FUNS IF A MERCHANT REFUSES THE PAYMENT',
#  'MY CARD PAYMENT WAS CANCELLED',
#  'WHEN WILL I RECEIVE A YU S TRANSFER',
#  'HOW LONG UNTIL THE MONEY IS IN MY ACCOUNT',
#  'HOW LONG DOES IT TAKE FOR A TRANSFER',
#  'WHAT IS THE NUMBER OF DAYS I HAVE TO WAIT FOR MY EUROPE TRANSFER',
#  'IF I STARTED THE BANK TRANSFER FROM EUROPE HOW LONG WILL THE PROCESS TAKE TO COMPLETE',
#  'HOW LONG DOES IT TAKE FOR FUNS TO COME THROUGH THE US TO MY ACCOUNT',
#  'WHEN SHOULD I EXPECT TO SEE MY TRANSFER HIT MY ACCOUNT',
#  'HOW LONG IS THE WAIT FOR A UAS TRANSFER',
#  'I DID NOT GET MY CARD YET IS IT LOST',
#  'WHY DOES MY MONEY COME FROM',
#  'HOW CAN I TELL WHERE MY FUNS CAME FROM',
#  'I HAVE TO VERIFY THE SOURCE OF MY FUNDS',
#  'CAN I VERIFY THE SOURCE OF MY FUNDS',
#  'HOW CAN I CHECK THE SOURCE OF FUNS',
#  'HELP ME CHECK WEAR THE FUNS CAME FROM',
#  'MY CARD WAS TAKEN BY THE EIGH T M',
#  "THE EIGHT M WON'T GIVE MY CARD BACK",
#  'I HAVE A PROBLEM THE A T M STOLE MY CARD',
#  'WHAT DO I DO IF AN A T M STOLE MY CARD',
#  'WHEN WILL I GET MY CARD',
#  'HOW CAN I GET MY CART OUT OF THE DAMAT M',
#  'I HAVE BEEN WAITING LONGER THAN EXPECTED FOR MY BANK CARD COULD YOU PROVIDE INFORMATION ON WHEN IT WILL ARRIVE',
#  'HOW LONG SHOULD MY NEW CARD TAKE TO ARRIVE',
#  'I ORDERED A CARD BUT IT HAS NOT ARRIVED HELP PLEASE',
#  "I ORDERED MY CARD TWO WEEKS AGO AND IT STILL ISN'T HERE WHAT DO I DO",
#  'I STILL HAVE NOT RECEIVED MY NEW CARD I ORDERED OVER A WEEK AGO',
#  'WHERE IS THE TRACKING NUMBER FOR THE CARD YOU SENT ME',
#  'DOES THE CARD YOU SENT HAVE A WAY TO TRACK TO IT',
#  'I AM STILL WAITING FOR MY CART AFTER ONE WEEK IS THIS O KU',
#  'I WANT TO TRACK THE CARD YOU SCENT',
#  'DO YOU KNOW IF THERE IS A TRACKING NUMBER FOR THE NEW CARD YOU SENT ME',
#  "I WAS EXPECTING MY NEW CARDAN AND WONDERING WHY I HAVEN'T RECEIVED IT YET",
#  "I ORDERED A CARD AND I STILL HAVEN'T RECEIVED IT IT'S BEEN TWO WEEKS WHAT CAN I DO",
#  'HOW DO I KNOW WHEN MY CARD WILL ARRIVE',
#  'STILL WAITING ON THAT CART',
#  'HOW DO I LOCATE MY CARD',
#  "MY CART HASN'T ARRIVED YET",
#  "MY CARD STILL HASN'T ARRIVED AFTER TWO WEEKS IS IT LOST",
#  'HOW LONG DOES A CARD DELIVERY TAKE',
#  "I'M STILL WAITING FOR DELIVERY OF MY NEW CARD WHY IS IT TAKING SO LONG",
#  "I'M STILL WAITING ON MY CARD TO BE DELIVERED",
#  "I'VE BEEN WAITING LONGER THAN EXPECTED FOR MY CARD",
#  'A TRANSACTION IS REPEATED SEVERAL TIMES ON MY ACCOUNT',
#  'CAN YOU PLEASE CHECK IF I WAS CHARGED TWICE',
#  'PLEASE CHECK PAYMENTS ON MY CART THERE IS A DUPLICATE AND I ONLY BOUGHT IT ONCE',
#  'I GOT DOUBLE CHARGED FOR A PAYMENT SO HOW DO I FIX THAT',
#  'IS IT NORMAL TO HAVE TO WAIT OVER A WEEK FOR MY NEW CART',
#  'I WAS WONDERING HOW I COULD HAVE TWO CHARGES FOR THE SAME ITEM HAPPEN MORE THAN ONCE IN A SEVEN DAY PERIOD IS THERE ANYWAY I COULD GET THIS CORRECTED A S A P',
#  'I SEE WHAT LOOKS LIKE DUPLICATE CHARGES ON ACCOUNT',
#  'IT APPEARS THAT I AM BEING DOUBLE CHARGED FOR SOME ITEMS THAT I HAVE PURCHASED THIS PAST WEEK PLEASE REVIEW AND CORRECT',
#  'WHY AM I BEING CHARGED TWICE',
#  'I WOULD LIKE TO KNOW WHY I WAS CHARGED TWICE FOR MY PURCHASE',
#  "I'VE BEEN CHARGED MORE THAN ONCE FOR THE SAME TRANSACTION",
#  'THERE IS MORE THAN ONE OF THE SAME TRANSACTION ON MY ACCOUNT',
#  "I DIDN'T BUY THIS TWICE",
#  'IT LOOKS LIKE THIS WEEK I WAS DOUBLE CHARGED FOR A COUPLE THINGS IS THERE ANY WAY THAT YOU CAN LOOK INTO THIS FOR ME AND RETURN THE DOUBLE CHARGED ITEMS BACK TO MY CART',
#  'I HAVE A DUPLICATE PAYMENT SHOWING',
#  "WHY HASN'T MY CARD BEEN DELIVERED",
#  'I HAVE A DUPLICATE PAYMENT SHOWING UP ON THE EP HOW DO I STOP MYSELF BEING CHARGED FOR THE THING TWICE',
#  'HELLO I CHECKED MY TRANSACTIONS AND SAW I WAS DOUBLE CHARGED ON MY CARD FOR A RESTAURANT VISIT I WOULD LIKE TO GET MY MONEY BACK',
#  'WHY WAS I JHULD TWICE FOR THE SAME THING',
#  'I THINK SOMETHING MAY HAVE HAPPENED THAT CAUSED A CHARGE TO SHOW UP TWICE',
#  'TRANSACTIONS ON MY CARRD LOOK REALLY WEIRD IAVE BEEN CHARGED TWICE FOR A COUPLE THINGS THIS WEEK PLEASE CHECK THIS IN RETURN THE DOUBLE CHARGED ONES',
#  'WHY AM I BEING CHARGED TWICE FOR OW A RESTAURANT',
#  'IHAVE JUST COME BACK FROM AN EATING HOLIDAY IN THE OU ESSAY AND CANADA AND HAVE SO MANY PENDING AND DUPLICATED TRANSACTIONS ON MY ACCOUNT I THINK THERE IS SOMETHING WRONG CAN YOU LOOK INTO IT PLEASE',
#  'WHAT ARE MY REMEDIES IF I THINK I WAS CHARGED TWICE FOR THE SAME EXPENSE',
#  'I HAVE A TRANSACTION THAT SHOWS SEVERAL TIMES',
#  'I NOTICED AFTER LOOKING OVER MY TRANSACTIONS THAT I HAVE BEEN CHARGED TWICE FROM AN EARLIER RESTAURANT VISIT THIS WEEK IS IT POSSIBLE THAT ONE OF THESE CAN BE REMOVED SO I GET THE MONEY BACK FOR THE ONE THAT IS NOT ACCURATE',
#  "I STILL DON'T HAVE MY CART AFTER TWO WEEKS WHAT SHOULD I DO",
#  'WHY HAVE I BEEN CHARGED TWICE FOR THE SAME TRANSACTION',
#  'WHY IS THERE MORE THAN ONE CHARGE ON MY CART I ONLY PAID FOR ONE NOT TWICE HOW CAN I FIX THIS',
#  'I WAS DOUBLE CHARGED',
#  'I RECENTLY GOT CHARGED TWICE FROM A RESTAURANT THAN I WAS AT THIS WEEK AND I WOULD LIKE FOR ONE OF THOSE PAYMENTS TO BE REMOVED FROM MY ACCOUNT',
#  'I HAVE MULTIPLED CHARGES ON THE SAME TRANSACTION',
#  'CAN MY FRIENDS SEND ME MONEY',
#  'MY SALARY IS RECEIVED IN THE FORM OF G B P DO I NEED TO DO ANYTHING SPECIFIC TO CONFIGURE THIS',
#  'I RECEIVED MY SALARY IN G B P HOW DO I CHANGE THIS TO MY CURRENCY',
#  'WILL SALARY BE RECEIVED THROUGH THIS',
#  'CAN I USE THIS TO RECEIVE MY SALARY',
#  'STATUS OF THE CARTD I ORDERED',
#  'WHAT DIFFERENT WAYS ARE THERE FOR SOME ONE TO SEND ME MONEY',
#  'IS G B P A SUPPORTED CURRENCY',
#  'CAN THIS BE USED TO RECEIVE MY CELLERY',
#  'CAN I GET MY SALARY THROUGH THIS',
#  'HOW DO I DEPOSIT MY PAY CHECK TO THIS ACCOUNT',
#  'IS MY SALARY ELIGIBLE FOR THIS',
#  'HOW CAN SOME ONE SEND ME MONEY',
#  'DO I NEED TO ESTABLISH I AM PAID IN G B P BEFORE A TRANSFER',
#  'MY SALARY IS IN G B P HOW CAN I NOTE THIS IN THE AP',
#  'I GET PAID IN G B P SHOULD I CONFIGURE THIS AND IF SO WHERE',
#  'IS THERE A WAY TO KNOW WHEN MY CARD WILL ARRIVE',
#  'CAN I DIRECTLY TRANSFER MY SALARY ONTO HERE',
#  'IS THERE A PROBLEM WITH RECEIVING MY SALARY IN G B P',
#  'HOW DO I GET MY SALARY IN THE ACCOUNT',
#  'IS IT POSSIBLE TO DEPOSIT MONEY IN G B P',
#  'CAN I RECEIVE MY SALARY IN OCCURRENCY OTHER THAN WHAT IT IS DEPOSITED IN',
#  'HOW CAN I GET PAID IN A DIFFERENT CURRENCY',
#  'CAN I GET MY PAYCHECK THROUGH HERE',
#  'CAN I TRANSFER MY SALARY OF ITS IN A DIFFERENT CURRENCY',
#  'THERE WAS AN EXTRA CHARGE WHEN I MADE A TRANSFER',
#  'I GOT TWO TRANSFER FEAS AND I THOUGHT TRANSFERS WERE FREE',
#  'I SENT OUT MONEY BUT WAS CHARGED EXTRA FOR TRANSFERRING WHY',
#  'WHEN I MADE A TRANSFER THERE WAS A FEET WHY',
#  'WHAT IS THE MAXIMUM I CAN TRANSFER BEFORE I IN CURFES',
#  'I WAS CHARGED MORE WHEN I TRANSFERRED',
#  'DO CHARGE FEES FOR YOUR TRANSFERS',
#  'MY RECEIPT SHOWS AN EXTRA CHARGE ON MY TRANSFER WHY IS THIS',
#  'WHY WAS A CHARGE JUST FOR TRANSFERRING',
#  "I NEED SOME ONE TO ALERT ME AS TO WHAT'S GOING ON I HAD TRANSFERRED AN AMOUNT BUT THE RECEIVER IS SAYING THAT THE AMOUNT IS SOMEWHAT LESS THAN WHAT I SENT OVER I NOW HAVE TO MAKE ANOTHER TRANSFER TO MAKE UP THE DIFFERENCE",
#  "I WAS CHARGED FOR SOMETHING I DIDN'T EXPECT",
#  'I HAD TO PAY IN ORDER TO DO A TRANSFER']

# %% [markdown]
# ### Note:
# Throughput will be a challenge! The model takes a while to provide all transcriptions. Should consider using a faster model (or pruning) as this will cause latency issues at scale.

# %% [markdown]
# # Text Clustering

# %%
def readFile(fileName):
    """
    This function will read the text files passed & return the list
    """
    fileObj = open(fileName, "r") #opens the file in read mode
    words = fileObj.read().splitlines() #puts the file into a list
    fileObj.close()
    return words

data = readFile('data.txt')
#data

# %%
data
# Out:
# ['WHAT IS THE TRACKING NUMBER FOR MY CART THAT WAS MAILED',
#  'HOW DO I TRACK MY CARD',
#  "I'M STARTING TO THINK MY CARD IS LOST BECAUSE IT STILL HASN'T ARRIVED CAN YOU HELP",
#  "I RECENTLY GOT A NEW PLACE WHILE I'M STAYING ABROAD AND HAVE BEEN USING THIS ACCOUNT TO MANAGE PAYMENTS BUT SUDDENLY I AM SEEING FEES INCREASE WHERE ARE THESE ADDITIONAL FEES COMING FROM",
#  'I PURCHASED SOME MAKE UP THROUGH A SIGHT IN CHINA AND I WAS UNDER THE IMPRESSION THAT WHEN I MAY TRANSFERS THERE IS NO FEE WHY AM I SEEING THIS FENOW I AM NOT HAPPY ABOUT THIS AT ALL',
#  "I'M NOT PAYING THIS TRANSFER FEE",
#  'I THOUGHT TRANSFERS WERE FREE WHY WAS I CHARGE TO FEE',
#  'WHAT IS THE TRANSFER F E CHARGE',
#  'WHY DID I GET CHARGED FOR SOMETHING I BOUGHT ON LINE EVEN THOUGH IT WAS INTERNATIONAL I THOUGHT IT WOULD BE COVERED',
#  "MY TRANSFER TO BENEFICIARY DIDN'T GO THROUGH",
#  "WHY CAN'T I TRANSFER TO A BENEFICIARY",
#  'WHY DID I RECEIVE AN ERROR MESSAGE SAYING THAT MY TRANSFER WAS NOT POSSIBLE',
#  "I'VE TROD NUMEROUS TIMES TO SUBMIT A TRANSFER OF FUNDS WHY ISN'T IT GOING THROUGH",
#  'MY CARD HAS NOT ARRIVED YET',
#  "I TRIED TO TRANSFER MONEY BUT IT SAID IT WASN'T POSSIBLE I'VE DONE THIS BEFORE AND IT WORKED WHY ISN'T IT WORKING NOW",
#  "I HAVE A CRIPTO CURRENCY EXCHANGE THAT WON'T GO THROUGH PLEASE HELP ME PROCESS IT",
#  "WHAT'S THE DEAL WITH NO CRYPTO CURRENCY ON YOUR RAP",
#  "I COULDN'T DO A TRANSFER TO AN ACCOUNT",
#  'I WAS UNABLE TO MAKE A TRANSFER TO ANOTHER ACCOUNT',
#  "WHY ISN'T MY TRANSFER GOING THROUGH I GET A MESSAGE SAYING IT'S NOT POSSIBLE I'VE HAD NO ISSUES IN THE PAST",
#  "WHY ISN'T MY ACCOUNT ALLOWING TRANSFERS",
#  'I HAD A TRANSFER BLOCKED',
#  "WHY ISN'T MY TRANSFER NOT GOING THROUGH I KEEP GETTING AN ARROR MESSAGE",
#  "I WANT TO BUY CRIPTO CURRENCY BUT YOUR AP DOESN'T LET ME WHY",
#  'STILL WAITING ON MY NEW CARD',
#  'WHY DID I GET A MESSAGE SAYING THAT MY TRANSFER IS NOT POSSIBLE I HAVE DONE THIS BEFORE NO PROBLEM PLEASE FIX',
#  'I NEED TO CHANGE MY PIN',
#  'I NEED A NEW PIN HOW DO I GO ABOUT THAT',
#  'DO CASH MACHINES LET ME CHANGE MY PIN',
#  'WHAT KIND OF CASH MACHINES WOULD ALLOW ME TO CHANGE MY PIN',
#  "I DESPERATELY NEED TO CHANGE MY PIN BUT I'M OVERSEEZ ON VACATION RIGHT NOW HOW CAN I DO THIS",
#  'MY NEW PIN NEEDS TO BE SET',
#  'IN WHAT AH T M CAN I CHANGE MY PIN',
#  'I AM TRAVELLING FOR TWO MORE WEEKS BUT REALLY NEED TO CHANGE MY PINA ES APING WHAT DO I DO',
#  'IF I AM OVERSEAS HOW DO I CHANGE MY PIN',
#  'IS THEIR TRACKING INFO AVAILABLE',
#  'MAY I RECEIVE A DIFFERENT CARD PEN',
#  'PLEASE TELL ME WHICH CASH MACHINES WILL ALLOW ME TO CHANGE MY PIN',
#  'CAN I CHANGE MY PIN AT THE AT M',
#  'THERE MUST BE AN ISSUE WHY HAS MY CARD BEEN CANCELLED',
#  'WHAT DO I DO IF IT SAYS MY CARD PAYMENT HAS BEEN KENCELLED',
#  'WHY WAS MY CARD PAYMENT KENCELLED',
#  'I THINK MY CARD PAYMENT HAS BEEN STOPPED',
#  'WHY HAS MY CARD PAYMENT BEEN CANSELLED',
#  'WHY WAS MY PAYMENT REVERSED',
#  'MY CARD IS BEING DECLINED FOR A PURCHASE I BOUGHT ITEMS BEFORE AND THE CARD WORKED DO YOU KNOW WHAT THE PROBLEM IS',
#  'I HAVE NOT RECEIVED MY CARD',
#  'WHAT HAPPENS TO THE FUNS IF A MERCHANT REFUSES THE PAYMENT',
#  'MY CARD PAYMENT WAS CANCELLED',
#  'WHEN WILL I RECEIVE A YU S TRANSFER',
#  'HOW LONG UNTIL THE MONEY IS IN MY ACCOUNT',
#  'HOW LONG DOES IT TAKE FOR A TRANSFER',
#  'WHAT IS THE NUMBER OF DAYS I HAVE TO WAIT FOR MY EUROPE TRANSFER',
#  'IF I STARTED THE BANK TRANSFER FROM EUROPE HOW LONG WILL THE PROCESS TAKE TO COMPLETE',
#  'HOW LONG DOES IT TAKE FOR FUNS TO COME THROUGH THE US TO MY ACCOUNT',
#  'WHEN SHOULD I EXPECT TO SEE MY TRANSFER HIT MY ACCOUNT',
#  'HOW LONG IS THE WAIT FOR A UAS TRANSFER',
#  'I DID NOT GET MY CARD YET IS IT LOST',
#  'WHY DOES MY MONEY COME FROM',
#  'HOW CAN I TELL WHERE MY FUNS CAME FROM',
#  'I HAVE TO VERIFY THE SOURCE OF MY FUNDS',
#  'CAN I VERIFY THE SOURCE OF MY FUNDS',
#  'HOW CAN I CHECK THE SOURCE OF FUNS',
#  'HELP ME CHECK WEAR THE FUNS CAME FROM',
#  'MY CARD WAS TAKEN BY THE EIGH T M',
#  "THE EIGHT M WON'T GIVE MY CARD BACK",
#  'I HAVE A PROBLEM THE A T M STOLE MY CARD',
#  'WHAT DO I DO IF AN A T M STOLE MY CARD',
#  'WHEN WILL I GET MY CARD',
#  'HOW CAN I GET MY CART OUT OF THE DAMAT M',
#  'I HAVE BEEN WAITING LONGER THAN EXPECTED FOR MY BANK CARD COULD YOU PROVIDE INFORMATION ON WHEN IT WILL ARRIVE',
#  'HOW LONG SHOULD MY NEW CARD TAKE TO ARRIVE',
#  'I ORDERED A CARD BUT IT HAS NOT ARRIVED HELP PLEASE',
#  "I ORDERED MY CARD TWO WEEKS AGO AND IT STILL ISN'T HERE WHAT DO I DO",
#  'I STILL HAVE NOT RECEIVED MY NEW CARD I ORDERED OVER A WEEK AGO',
#  'WHERE IS THE TRACKING NUMBER FOR THE CARD YOU SENT ME',
#  'DOES THE CARD YOU SENT HAVE A WAY TO TRACK TO IT',
#  'I AM STILL WAITING FOR MY CART AFTER ONE WEEK IS THIS O KU',
#  'I WANT TO TRACK THE CARD YOU SCENT',
#  'DO YOU KNOW IF THERE IS A TRACKING NUMBER FOR THE NEW CARD YOU SENT ME',
#  "I WAS EXPECTING MY NEW CARDAN AND WONDERING WHY I HAVEN'T RECEIVED IT YET",
#  "I ORDERED A CARD AND I STILL HAVEN'T RECEIVED IT IT'S BEEN TWO WEEKS WHAT CAN I DO",
#  'HOW DO I KNOW WHEN MY CARD WILL ARRIVE',
#  'STILL WAITING ON THAT CART',
#  'HOW DO I LOCATE MY CARD',
#  "MY CART HASN'T ARRIVED YET",
#  "MY CARD STILL HASN'T ARRIVED AFTER TWO WEEKS IS IT LOST",
#  'HOW LONG DOES A CARD DELIVERY TAKE',
#  "I'M STILL WAITING FOR DELIVERY OF MY NEW CARD WHY IS IT TAKING SO LONG",
#  "I'M STILL WAITING ON MY CARD TO BE DELIVERED",
#  "I'VE BEEN WAITING LONGER THAN EXPECTED FOR MY CARD",
#  'A TRANSACTION IS REPEATED SEVERAL TIMES ON MY ACCOUNT',
#  'CAN YOU PLEASE CHECK IF I WAS CHARGED TWICE',
#  'PLEASE CHECK PAYMENTS ON MY CART THERE IS A DUPLICATE AND I ONLY BOUGHT IT ONCE',
#  'I GOT DOUBLE CHARGED FOR A PAYMENT SO HOW DO I FIX THAT',
#  'IS IT NORMAL TO HAVE TO WAIT OVER A WEEK FOR MY NEW CART',
#  'I WAS WONDERING HOW I COULD HAVE TWO CHARGES FOR THE SAME ITEM HAPPEN MORE THAN ONCE IN A SEVEN DAY PERIOD IS THERE ANYWAY I COULD GET THIS CORRECTED A S A P',
#  'I SEE WHAT LOOKS LIKE DUPLICATE CHARGES ON ACCOUNT',
#  'IT APPEARS THAT I AM BEING DOUBLE CHARGED FOR SOME ITEMS THAT I HAVE PURCHASED THIS PAST WEEK PLEASE REVIEW AND CORRECT',
#  'WHY AM I BEING CHARGED TWICE',
#  'I WOULD LIKE TO KNOW WHY I WAS CHARGED TWICE FOR MY PURCHASE',
#  "I'VE BEEN CHARGED MORE THAN ONCE FOR THE SAME TRANSACTION",
#  'THERE IS MORE THAN ONE OF THE SAME TRANSACTION ON MY ACCOUNT',
#  "I DIDN'T BUY THIS TWICE",
#  'IT LOOKS LIKE THIS WEEK I WAS DOUBLE CHARGED FOR A COUPLE THINGS IS THERE ANY WAY THAT YOU CAN LOOK INTO THIS FOR ME AND RETURN THE DOUBLE CHARGED ITEMS BACK TO MY CART',
#  'I HAVE A DUPLICATE PAYMENT SHOWING',
#  "WHY HASN'T MY CARD BEEN DELIVERED",
#  'I HAVE A DUPLICATE PAYMENT SHOWING UP ON THE EP HOW DO I STOP MYSELF BEING CHARGED FOR THE THING TWICE',
#  'HELLO I CHECKED MY TRANSACTIONS AND SAW I WAS DOUBLE CHARGED ON MY CARD FOR A RESTAURANT VISIT I WOULD LIKE TO GET MY MONEY BACK',
#  'WHY WAS I JHULD TWICE FOR THE SAME THING',
#  'I THINK SOMETHING MAY HAVE HAPPENED THAT CAUSED A CHARGE TO SHOW UP TWICE',
#  'TRANSACTIONS ON MY CARRD LOOK REALLY WEIRD IAVE BEEN CHARGED TWICE FOR A COUPLE THINGS THIS WEEK PLEASE CHECK THIS IN RETURN THE DOUBLE CHARGED ONES',
#  'WHY AM I BEING CHARGED TWICE FOR OW A RESTAURANT',
#  'IHAVE JUST COME BACK FROM AN EATING HOLIDAY IN THE OU ESSAY AND CANADA AND HAVE SO MANY PENDING AND DUPLICATED TRANSACTIONS ON MY ACCOUNT I THINK THERE IS SOMETHING WRONG CAN YOU LOOK INTO IT PLEASE',
#  'WHAT ARE MY REMEDIES IF I THINK I WAS CHARGED TWICE FOR THE SAME EXPENSE',
#  'I HAVE A TRANSACTION THAT SHOWS SEVERAL TIMES',
#  'I NOTICED AFTER LOOKING OVER MY TRANSACTIONS THAT I HAVE BEEN CHARGED TWICE FROM AN EARLIER RESTAURANT VISIT THIS WEEK IS IT POSSIBLE THAT ONE OF THESE CAN BE REMOVED SO I GET THE MONEY BACK FOR THE ONE THAT IS NOT ACCURATE',
#  "I STILL DON'T HAVE MY CART AFTER TWO WEEKS WHAT SHOULD I DO",
#  'WHY HAVE I BEEN CHARGED TWICE FOR THE SAME TRANSACTION',
#  'WHY IS THERE MORE THAN ONE CHARGE ON MY CART I ONLY PAID FOR ONE NOT TWICE HOW CAN I FIX THIS',
#  'I WAS DOUBLE CHARGED',
#  'I RECENTLY GOT CHARGED TWICE FROM A RESTAURANT THAN I WAS AT THIS WEEK AND I WOULD LIKE FOR ONE OF THOSE PAYMENTS TO BE REMOVED FROM MY ACCOUNT',
#  'I HAVE MULTIPLED CHARGES ON THE SAME TRANSACTION',
#  'CAN MY FRIENDS SEND ME MONEY',
#  'MY SALARY IS RECEIVED IN THE FORM OF G B P DO I NEED TO DO ANYTHING SPECIFIC TO CONFIGURE THIS',
#  'I RECEIVED MY SALARY IN G B P HOW DO I CHANGE THIS TO MY CURRENCY',
#  'WILL SALARY BE RECEIVED THROUGH THIS',
#  'CAN I USE THIS TO RECEIVE MY SALARY',
#  'STATUS OF THE CARTD I ORDERED',
#  'WHAT DIFFERENT WAYS ARE THERE FOR SOME ONE TO SEND ME MONEY',
#  'IS G B P A SUPPORTED CURRENCY',
#  'CAN THIS BE USED TO RECEIVE MY CELLERY',
#  'CAN I GET MY SALARY THROUGH THIS',
#  'HOW DO I DEPOSIT MY PAY CHECK TO THIS ACCOUNT',
#  'IS MY SALARY ELIGIBLE FOR THIS',
#  'HOW CAN SOME ONE SEND ME MONEY',
#  'DO I NEED TO ESTABLISH I AM PAID IN G B P BEFORE A TRANSFER',
#  'MY SALARY IS IN G B P HOW CAN I NOTE THIS IN THE AP',
#  'I GET PAID IN G B P SHOULD I CONFIGURE THIS AND IF SO WHERE',
#  'IS THERE A WAY TO KNOW WHEN MY CARD WILL ARRIVE',
#  'CAN I DIRECTLY TRANSFER MY SALARY ONTO HERE',
#  'IS THERE A PROBLEM WITH RECEIVING MY SALARY IN G B P',
#  'HOW DO I GET MY SALARY IN THE ACCOUNT',
#  'IS IT POSSIBLE TO DEPOSIT MONEY IN G B P',
#  'CAN I RECEIVE MY SALARY IN OCCURRENCY OTHER THAN WHAT IT IS DEPOSITED IN',
#  'HOW CAN I GET PAID IN A DIFFERENT CURRENCY',
#  'CAN I GET MY PAYCHECK THROUGH HERE',
#  'CAN I TRANSFER MY SALARY OF ITS IN A DIFFERENT CURRENCY',
#  'THERE WAS AN EXTRA CHARGE WHEN I MADE A TRANSFER',
#  'I GOT TWO TRANSFER FEAS AND I THOUGHT TRANSFERS WERE FREE',
#  'I SENT OUT MONEY BUT WAS CHARGED EXTRA FOR TRANSFERRING WHY',
#  'WHEN I MADE A TRANSFER THERE WAS A FEET WHY',
#  'WHAT IS THE MAXIMUM I CAN TRANSFER BEFORE I IN CURFES',
#  'I WAS CHARGED MORE WHEN I TRANSFERRED',
#  'DO CHARGE FEES FOR YOUR TRANSFERS',
#  'MY RECEIPT SHOWS AN EXTRA CHARGE ON MY TRANSFER WHY IS THIS',
#  'WHY WAS A CHARGE JUST FOR TRANSFERRING',
#  "I NEED SOME ONE TO ALERT ME AS TO WHAT'S GOING ON I HAD TRANSFERRED AN AMOUNT BUT THE RECEIVER IS SAYING THAT THE AMOUNT IS SOMEWHAT LESS THAN WHAT I SENT OVER I NOW HAVE TO MAKE ANOTHER TRANSFER TO MAKE UP THE DIFFERENCE",
#  "I WAS CHARGED FOR SOMETHING I DIDN'T EXPECT",
#  'I HAD TO PAY IN ORDER TO DO A TRANSFER']

# %% [markdown]
# ## Tokenise and Remove Stopwords

# %%
nltk.download('punkt')
nltk.download('stopwords')
import nltk
from nltk.corpus import stopwords

# Get english stop words
en_stopwords = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Theodore\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
from nltk.tokenize import sent_tokenize, word_tokenize

def tokenise_remove_stopwords(data):
        """ Takes in textual data, converts it to lowercase, tokenises and removes stopwords
    Args:
        list of strings (str): input string
    Returns:
        list: a list of tokens with stopwords removed
    """
    filtered_words = []
    for i in np.arange(0,len(data)):
        words = word_tokenize(data[i].lower())
        for w in words:
            if w not in en_stopwords:
                filtered_words.append(w)
    print(filtered_words)
# Out:
# ['tracking', 'number', 'cart', 'mailed', 'track', 'card', "'m", 'starting', 'think', 'card', 'lost', 'still', "n't", 'arrived', 'help', 'recently', 'got', 'new', 'place', "'m", 'staying', 'abroad', 'using', 'account', 'manage', 'payments', 'suddenly', 'seeing', 'fees', 'increase', 'additional', 'fees', 'coming', 'purchased', 'make', 'sight', 'china', 'impression', 'may', 'transfers', 'fee', 'seeing', 'fenow', 'happy', "'m", 'paying', 'transfer', 'fee', 'thought', 'transfers', 'free', 'charge', 'fee', 'transfer', 'f', 'e', 'charge', 'get', 'charged', 'something', 'bought', 'line', 'even', 'though', 'international', 'thought', 'would', 'covered', 'transfer', 'beneficiary', "n't", 'go', 'ca', "n't", 'transfer', 'beneficiary', 'receive', 'error', 'message', 'saying', 'transfer', 'possible', "'ve", 'trod', 'numerous', 'times', 'submit', 'transfer', 'funds', "n't", 'going', 'card', 'arrived', 'yet', 'tried', 'transfer', 'money', 'said', "n't", 'possible', "'ve", 'done', 'worked', "n't", 'working', 'cripto', 'currency', 'exchange', 'wo', "n't", 'go', 'please', 'help', 'process', "'s", 'deal', 'crypto', 'currency', 'rap', 'could', "n't", 'transfer', 'account', 'unable', 'make', 'transfer', 'another', 'account', "n't", 'transfer', 'going', 'get', 'message', 'saying', "'s", 'possible', "'ve", 'issues', 'past', "n't", 'account', 'allowing', 'transfers', 'transfer', 'blocked', "n't", 'transfer', 'going', 'keep', 'getting', 'arror', 'message', 'want', 'buy', 'cripto', 'currency', 'ap', "n't", 'let', 'still', 'waiting', 'new', 'card', 'get', 'message', 'saying', 'transfer', 'possible', 'done', 'problem', 'please', 'fix', 'need', 'change', 'pin', 'need', 'new', 'pin', 'go', 'cash', 'machines', 'let', 'change', 'pin', 'kind', 'cash', 'machines', 'would', 'allow', 'change', 'pin', 'desperately', 'need', 'change', 'pin', "'m", 'overseez', 'vacation', 'right', 'new', 'pin', 'needs', 'set', 'ah', 'change', 'pin', 'travelling', 'two', 'weeks', 'really', 'need', 'change', 'pina', 'es', 'aping', 'overseas', 'change', 'pin', 'tracking', 'info', 'available', 'may', 'receive', 'different', 'card', 'pen', 'please', 'tell', 'cash', 'machines', 'allow', 'change', 'pin', 'change', 'pin', 'must', 'issue', 'card', 'cancelled', 'says', 'card', 'payment', 'kencelled', 'card', 'payment', 'kencelled', 'think', 'card', 'payment', 'stopped', 'card', 'payment', 'canselled', 'payment', 'reversed', 'card', 'declined', 'purchase', 'bought', 'items', 'card', 'worked', 'know', 'problem', 'received', 'card', 'happens', 'funs', 'merchant', 'refuses', 'payment', 'card', 'payment', 'cancelled', 'receive', 'yu', 'transfer', 'long', 'money', 'account', 'long', 'take', 'transfer', 'number', 'days', 'wait', 'europe', 'transfer', 'started', 'bank', 'transfer', 'europe', 'long', 'process', 'take', 'complete', 'long', 'take', 'funs', 'come', 'us', 'account', 'expect', 'see', 'transfer', 'hit', 'account', 'long', 'wait', 'uas', 'transfer', 'get', 'card', 'yet', 'lost', 'money', 'come', 'tell', 'funs', 'came', 'verify', 'source', 'funds', 'verify', 'source', 'funds', 'check', 'source', 'funs', 'help', 'check', 'wear', 'funs', 'came', 'card', 'taken', 'eigh', 'eight', 'wo', "n't", 'give', 'card', 'back', 'problem', 'stole', 'card', 'stole', 'card', 'get', 'card', 'get', 'cart', 'damat', 'waiting', 'longer', 'expected', 'bank', 'card', 'could', 'provide', 'information', 'arrive', 'long', 'new', 'card', 'take', 'arrive', 'ordered', 'card', 'arrived', 'help', 'please', 'ordered', 'card', 'two', 'weeks', 'ago', 'still', "n't", 'still', 'received', 'new', 'card', 'ordered', 'week', 'ago', 'tracking', 'number', 'card', 'sent', 'card', 'sent', 'way', 'track', 'still', 'waiting', 'cart', 'one', 'week', 'ku', 'want', 'track', 'card', 'scent', 'know', 'tracking', 'number', 'new', 'card', 'sent', 'expecting', 'new', 'cardan', 'wondering', "n't", 'received', 'yet', 'ordered', 'card', 'still', "n't", 'received', "'s", 'two', 'weeks', 'know', 'card', 'arrive', 'still', 'waiting', 'cart', 'locate', ...

# %% [markdown]
# ## Clustering with BERT embeddings

# %%
# !pip install -U sentence-transformers
# Out:
# Collecting sentence-transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ---------------------------------------- 86.0/86.0 kB 1.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from sentence-transformers) (4.21.2)
# Requirement already satisfied: tqdm in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from sentence-transformers) (4.64.0)
# Requirement already satisfied: torch>=1.6.0 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from sentence-transformers) (1.12.1)
# Collecting torchvision
#   Downloading torchvision-0.13.1-cp39-cp39-win_amd64.whl (1.1 MB)
#      ---------------------------------------- 1.1/1.1 MB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from sentence-transformers) (1.22.4)
# Requirement already satisfied: scikit-learn in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from sentence-transformers) (1.1.1)
# Requirement already satisfied: scipy in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from sentence-transformers) (1.8.1)
# Requirement already satisfied: nltk in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from sentence-transformers) (3.7)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp39-cp39-win_amd64.whl (1.1 MB)
#      ---------------------------------------- 1.1/1.1 MB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub>=0.4.0 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from sentence-transformers) (0.9.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (6.0)
# Requirement already satisfied: filelock in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.8.0)
# Requirement already satisfied: requests in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.28.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.3.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2022.8.17)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.12.1)
# Requirement already satisfied: colorama in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from tqdm->sentence-transformers) (0.4.5)
# Requirement already satisfied: click in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from nltk->sentence-transformers) (8.1.3)
# Requirement already satisfied: joblib in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from nltk->sentence-transformers) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from scikit-learn->sentence-transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from torchvision->sentence-transformers) (9.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from packaging>=20.9->huggingface-hub>=0.4.0->sentence-transformers) (3.0.9)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\theodore\appdata\local\programs\python\python39\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2.1.0)
# Using legacy 'setup.py install' for sentence-transformers, since package 'wheel' is not installed.
# Installing collected packages: sentencepiece, torchvision, sentence-transformers
#   Running setup.py install for sentence-transformers: started
#   Running setup.py install for sentence-transformers: finished with status 'done'
# Successfully installed sentence-transformers-2.2.2 sentencepiece-0.1.97 torchvision-0.13.1
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sentence_transformers import SentenceTransformer
from sklearn.cluster import KMeans

embedder = SentenceTransformer('distilbert-base-nli-stsb-mean-tokens')
corpus_embeddings = embedder.encode(data)

num_clusters = 10
clustering_model = KMeans(n_clusters=num_clusters) # Define kmeans model
clustering_model.fit(corpus_embeddings) # Fit the embedding with kmeans clustering.
cluster_assignment = clustering_model.labels_ # Get the cluster id assigned to each news headline.

clustered_sentences = [[] for i in range(num_clusters)]
for sentence_id, cluster_id in enumerate(cluster_assignment):
    clustered_sentences[cluster_id].append(data[sentence_id])
for i, cluster in enumerate(clustered_sentences):
    print("Cluster ", i+1)
    print(cluster)
    print("")
# Out:
# Cluster  1
# ['WHEN WILL I RECEIVE A YU S TRANSFER', 'HOW LONG DOES IT TAKE FOR A TRANSFER', 'WHAT IS THE NUMBER OF DAYS I HAVE TO WAIT FOR MY EUROPE TRANSFER', 'IF I STARTED THE BANK TRANSFER FROM EUROPE HOW LONG WILL THE PROCESS TAKE TO COMPLETE', 'HOW LONG IS THE WAIT FOR A UAS TRANSFER', 'IS IT NORMAL TO HAVE TO WAIT OVER A WEEK FOR MY NEW CART', "I STILL DON'T HAVE MY CART AFTER TWO WEEKS WHAT SHOULD I DO"]
#
# Cluster  2
# ['HOW LONG UNTIL THE MONEY IS IN MY ACCOUNT', 'WHEN SHOULD I EXPECT TO SEE MY TRANSFER HIT MY ACCOUNT', 'I HAVE TO VERIFY THE SOURCE OF MY FUNDS', 'CAN I VERIFY THE SOURCE OF MY FUNDS', 'A TRANSACTION IS REPEATED SEVERAL TIMES ON MY ACCOUNT', 'THERE IS MORE THAN ONE OF THE SAME TRANSACTION ON MY ACCOUNT', 'CAN MY FRIENDS SEND ME MONEY', 'WHAT DIFFERENT WAYS ARE THERE FOR SOME ONE TO SEND ME MONEY', 'HOW DO I DEPOSIT MY PAY CHECK TO THIS ACCOUNT', 'HOW CAN SOME ONE SEND ME MONEY', 'HOW DO I GET MY SALARY IN THE ACCOUNT', 'CAN I GET MY PAYCHECK THROUGH HERE']
#
# Cluster  3
# ['I NEED TO CHANGE MY PIN', 'I NEED A NEW PIN HOW DO I GO ABOUT THAT', 'DO CASH MACHINES LET ME CHANGE MY PIN', 'WHAT KIND OF CASH MACHINES WOULD ALLOW ME TO CHANGE MY PIN', 'MY NEW PIN NEEDS TO BE SET', 'IN WHAT AH T M CAN I CHANGE MY PIN', 'IF I AM OVERSEAS HOW DO I CHANGE MY PIN', 'MAY I RECEIVE A DIFFERENT CARD PEN', 'PLEASE TELL ME WHICH CASH MACHINES WILL ALLOW ME TO CHANGE MY PIN', 'CAN I CHANGE MY PIN AT THE AT M']
#
# Cluster  4
# ["I RECENTLY GOT A NEW PLACE WHILE I'M STAYING ABROAD AND HAVE BEEN USING THIS ACCOUNT TO MANAGE PAYMENTS BUT SUDDENLY I AM SEEING FEES INCREASE WHERE ARE THESE ADDITIONAL FEES COMING FROM", 'I PURCHASED SOME MAKE UP THROUGH A SIGHT IN CHINA AND I WAS UNDER THE IMPRESSION THAT WHEN I MAY TRANSFERS THERE IS NO FEE WHY AM I SEEING THIS FENOW I AM NOT HAPPY ABOUT THIS AT ALL', "I'M NOT PAYING THIS TRANSFER FEE", 'WHY DID I GET CHARGED FOR SOMETHING I BOUGHT ON LINE EVEN THOUGH IT WAS INTERNATIONAL I THOUGHT IT WOULD BE COVERED', "MY TRANSFER TO BENEFICIARY DIDN'T GO THROUGH", 'WHY DID I RECEIVE AN ERROR MESSAGE SAYING THAT MY TRANSFER WAS NOT POSSIBLE', "I'VE TROD NUMEROUS TIMES TO SUBMIT A TRANSFER OF FUNDS WHY ISN'T IT GOING THROUGH", "I TRIED TO TRANSFER MONEY BUT IT SAID IT WASN'T POSSIBLE I'VE DONE THIS BEFORE AND IT WORKED WHY ISN'T IT WORKING NOW", "WHY ISN'T MY TRANSFER GOING THROUGH I GET A MESSAGE SAYING IT'S NOT POSSIBLE I'VE HAD NO ISSUES IN THE PAST", 'I HAD A TRANSFER BLOCKED', "WHY ISN'T MY TRANSFER NOT GOING THROUGH I KEEP GETTING AN ARROR MESSAGE", "I WANT TO BUY CRIPTO CURRENCY BUT YOUR AP DOESN'T LET ME WHY", 'WHY DID I GET A MESSAGE SAYING THAT MY TRANSFER IS NOT POSSIBLE I HAVE DONE THIS BEFORE NO PROBLEM PLEASE FIX', "I DESPERATELY NEED TO CHANGE MY PIN BUT I'M OVERSEEZ ON VACATION RIGHT NOW HOW CAN I DO THIS", 'I AM TRAVELLING FOR TWO MORE WEEKS BUT REALLY NEED TO CHANGE MY PINA ES APING WHAT DO I DO', 'I WAS WONDERING HOW I COULD HAVE TWO CHARGES FOR THE SAME ITEM HAPPEN MORE THAN ONCE IN A SEVEN DAY PERIOD IS THERE ANYWAY I COULD GET THIS CORRECTED A S A P', 'IHAVE JUST COME BACK FROM AN EATING HOLIDAY IN THE OU ESSAY AND CANADA AND HAVE SO MANY PENDING AND DUPLICATED TRANSACTIONS ON MY ACCOUNT I THINK THERE IS SOMETHING WRONG CAN YOU LOOK INTO IT PLEASE', 'I NOTICED AFTER LOOKING OVER MY TRANSACTIONS THAT I HAVE BEEN CHARGED TWICE FROM AN EARLIER RESTAURANT VISIT THIS WEEK IS IT POSSIBLE THAT ONE OF THESE CAN BE REMOVED SO I GET THE MONEY BACK FOR THE ONE THAT IS NOT ACCURATE', 'WHY IS THERE MORE THAN ONE CHARGE ON MY CART I ONLY PAID FOR ONE NOT TWICE HOW CAN I FIX THIS', 'I RECENTLY GOT CHARGED TWICE FROM A RESTAURANT THAN I WAS AT THIS WEEK AND I WOULD LIKE FOR ONE OF THOSE PAYMENTS TO BE REMOVED FROM MY ACCOUNT', 'THERE WAS AN EXTRA CHARGE WHEN I MADE A TRANSFER', 'I GOT TWO TRANSFER FEAS AND I THOUGHT TRANSFERS WERE FREE', 'WHEN I MADE A TRANSFER THERE WAS A FEET WHY', 'WHAT IS THE MAXIMUM I CAN TRANSFER BEFORE I IN CURFES', 'I WAS CHARGED MORE WHEN I TRANSFERRED', "I NEED SOME ONE TO ALERT ME AS TO WHAT'S GOING ON I HAD TRANSFERRED AN AMOUNT BUT THE RECEIVER IS SAYING THAT THE AMOUNT IS SOMEWHAT LESS THAN WHAT I SENT OVER I NOW HAVE TO MAKE ANOTHER TRANSFER TO MAKE UP THE DIFFERENCE", "I WAS CHARGED FOR SOMETHING I DIDN'T EXPECT"]
#
# Cluster  5
# ['STILL WAITING ON MY NEW CARD', 'I HAVE BEEN WAITING LONGER THAN EXPECTED FOR MY BANK CARD COULD YOU PROVIDE INFORMATION ON WHEN IT WILL ARRIVE', 'HOW LONG SHOULD MY NEW CARD TAKE TO ARRIVE', "I ORDERED MY CARD TWO WEEKS AGO AND IT STILL ISN'T HERE WHAT DO I DO", 'I STILL HAVE NOT RECEIVED MY NEW CARD I ORDERED OVER A WEEK AGO', 'I AM STILL WAITING FOR MY CART AFTER ONE WEEK IS THIS O KU', "I WAS EXPECTING MY NEW CARDAN AND WONDERING WHY I HAVEN'T RECEIVED IT YET", "I ORDERED A CARD AND I STILL HAVEN'T RECEIVED IT IT'S BEEN TWO WEEKS WHAT CAN I DO", 'STILL WAITING ON THAT CART', "I'M STILL WAITING FOR DELIVERY OF MY NEW CARD WHY IS IT TAKING SO LONG", "I'M STILL WAITING ON MY CARD TO BE DELIVERED", "I'VE BEEN WAITING LONGER THAN EXPECTED FOR MY CARD", 'I HAVE A TRANSACTION THAT SHOWS SEVERAL TIMES']
#
# Cluster  6
# ['HOW DO I TRACK MY CARD', 'IS THEIR TRACKING INFO AVAILABLE', 'WHEN WILL I GET MY CARD', 'WHERE IS THE TRACKING NUMBER FOR THE CARD YOU SENT ME', 'DOES THE CARD YOU SENT HAVE A WAY TO TRACK TO IT', 'I WANT TO TRACK THE CARD YOU SCENT', 'DO YOU KNOW IF THERE IS A TRACKING NUMBER FOR THE NEW CARD YOU SENT ME', 'HOW DO I KNOW WHEN MY CARD WILL ARRIVE', 'HOW DO I LOCATE MY CARD', 'HOW LONG DOES A CARD DELIVERY TAKE', 'IS THERE A WAY TO KNOW WHEN MY CARD WILL ARRIVE']
#
# Cluster  7
# ['WHAT IS THE TRACKING NUMBER FOR MY CART THAT WAS MAILED', 'I THOUGHT TRANSFERS WERE FREE WHY WAS I CHARGE TO FEE', 'WHAT IS THE TRANSFER F E CHARGE', "WHAT'S THE DEAL WITH NO CRYPTO CURRENCY ON YOUR RAP", 'WHAT DO I DO IF IT SAYS MY CARD PAYMENT HAS BEEN KENCELLED', 'WHY WAS MY CARD PAYMENT KENCELLED', 'WHY HAS MY CARD PAYMENT BEEN CANSELLED', 'WHY WAS MY PAYMENT REVERSED', 'WHAT HAPPENS TO THE FUNS IF A MERCHANT REFUSES THE PAYMENT', 'HOW LONG DOES IT TAKE FOR FUNS TO COME THROUGH THE US TO MY ACCOUNT', 'WHY DOES MY MONEY COME FROM', 'HOW CAN I TELL WHERE MY FUNS CAME FROM', 'HOW CAN I CHECK THE SOURCE OF FUNS', 'HELP ME CHECK WEAR THE FUNS CAME FROM', 'MY CARD WAS TAKEN BY THE EIGH T M', 'HOW CAN I GET MY CART OUT OF THE DAMAT M', 'WHY WAS I JHULD TWICE FOR THE SAME THING', 'WHY AM I BEING CHARGED TWICE FOR OW A RESTAURANT', 'STATUS OF THE CARTD I ORDERED', 'CAN THIS BE USED TO RECEIVE MY CELLERY', 'I SENT OUT MONEY BUT WAS CHARGED EXTRA FOR TRANSFERRING WHY', 'MY RECEIPT SHOWS AN EXTRA CHARGE ON MY TRANSFER WHY IS THIS', 'WHY WAS A CHARGE JUST FOR TRANSFERRING']
#
# Cluster  8
# ["WHY CAN'T I TRANSFER TO A BENEFICIARY", 'MY SALARY IS RECEIVED IN THE FORM OF G B P DO I NEED TO DO ANYTHING SPECIFIC TO CONFIGURE THIS', 'I RECEIVED MY SALARY IN G B P HOW DO I CHANGE THIS TO MY CURRENCY', 'WILL SALARY BE RECEIVED THROUGH THIS', 'CAN I USE THIS TO RECEIVE MY SALARY', 'IS G B P A SUPPORTED CURRENCY', 'CAN I GET MY SALARY THROUGH THIS', 'IS MY SALARY ELIGIBLE FOR THIS', 'DO I NEED TO ESTABLISH I AM PAID IN G B P BEFORE A TRANSFER', 'MY SALARY IS IN G B P HOW CAN I NOTE THIS IN THE AP', 'I GET PAID IN G B P SHOULD I CONFIGURE THIS AND IF SO WHERE', 'CAN I DIRECTLY TRANSFER MY SALARY ONTO HERE', 'IS THERE A PROBLEM WITH RECEIVING MY SALARY IN G B P', 'IS IT POSSIBLE TO DEPOSIT MONEY IN G B P', 'CAN I RECEIVE MY SALARY IN OCCURRENCY OTHER THAN WHAT IT IS DEPOSITED IN', 'HOW CAN I GET PAID IN A DIFFERENT CURRENCY', 'CAN I TRANSFER MY SALARY OF ITS IN A DIFFERENT CURRENCY', 'DO CHARGE FEES FOR YOUR TRANSFERS', 'I HAD TO PAY IN ORDER TO DO A TRANSFER']
#
# Cluster  9
# ['CAN YOU PLEASE CHECK IF I WAS CHARGED TWICE', 'PLEASE CHECK PAYMENTS ON MY CART THERE IS A DUPLICATE AND I ONLY BOUGHT IT ONCE', 'I GOT DOUBLE CHARGED FOR A PAYMENT SO HOW DO I FIX THAT', 'I SEE WHAT LOOKS LIKE DUPLICATE CHARGES ON ACCOUNT', 'IT APPEARS THAT I AM BEING DOUBLE CHARGED FOR SOME ITEMS THAT I HAVE PURCHASED THIS PAST WEEK PLEASE REVIEW AND CORRECT', 'WHY AM I BEING CHARGED TWICE', 'I WOULD LIKE TO KNOW WHY I WAS CHARGED TWICE FOR MY PURCHASE', "I'VE BEEN CHARGED MORE THAN ONCE FOR THE SAME TRANSACTION", 'IT LOOKS LIKE THIS WEEK I WAS DOUBLE CHARGED FOR A COUPLE THINGS IS THERE ANY WAY THAT YOU CAN LOOK INTO THIS FOR ME AND RETURN THE DOUBLE CHARGED ITEMS BACK TO MY CART', 'I HAVE A DUPLICATE PAYMENT SHOWING', 'I HAVE A DUPLICATE PAYMENT SHOWING UP ON THE EP HOW DO I STOP MYSELF BEING CHARGED FOR THE THING TWICE', 'HELLO I CHECKED MY TRANSACTIONS AND SAW I WAS DOUBLE CHARGED ON MY CARD FOR A RESTAURANT VISIT I WOULD LIKE TO GET MY MONEY BACK', 'I THINK SOMETHING MAY HAVE HAPPENED THAT CAUSED A CHARGE TO SHOW UP TWICE', 'TRANSACTIONS ON MY CARRD LOOK REALLY WEIRD IAVE BEEN CHARGED TWICE FOR A COUPLE THINGS THIS WEEK PLEASE CHECK THIS IN RETURN THE DOUBLE CHARGED ONES', 'WHAT ARE MY REMEDIES IF I THINK I WAS CHARGED TWICE FOR THE SAME EXPENSE', 'WHY HAVE I BEEN CHARGED TWICE FOR THE SAME TRANSACTION', 'I WAS DOUBLE CHARGED', 'I HAVE MULTIPLED CHARGES ON THE SAME TRANSACTION']
#
# Cluster  10
# ["I'M STARTING TO THINK MY CARD IS LOST BECAUSE IT STILL HASN'T ARRIVED CAN YOU HELP", 'MY CARD HAS NOT ARRIVED YET', "I HAVE A CRIPTO CURRENCY EXCHANGE THAT WON'T GO THROUGH PLEASE HELP ME PROCESS IT", "I COULDN'T DO A TRANSFER TO AN ACCOUNT", 'I WAS UNABLE TO MAKE A TRANSFER TO ANOTHER ACCOUNT', "WHY ISN'T MY ACCOUNT ALLOWING TRANSFERS", 'THERE MUST BE AN ISSUE WHY HAS MY CARD BEEN CANCELLED', 'I THINK MY CARD PAYMENT HAS BEEN STOPPED', 'MY CARD IS BEING DECLINED FOR A PURCHASE I BOUGHT ITEMS BEFORE AND THE CARD WORKED DO YOU KNOW WHAT THE PROBLEM IS', 'I HAVE NOT RECEIVED MY CARD', 'MY CARD PAYMENT WAS CANCELLED', 'I DID NOT GET MY CARD YET IS IT LOST', "THE EIGHT M WON'T GIVE MY CARD BACK", 'I HAVE A PROBLEM THE A T M STOLE MY CARD', 'WHAT DO I DO IF AN A T M STOLE MY CARD', 'I ORDERED A CARD BUT IT HAS NOT ARRIVED HELP PLEASE', "MY CART HASN'T ARRIVED YET", "MY CARD STILL HASN'T ARRIVED AFTER TWO WEEKS IS IT LOST", "I DIDN'T BUY THIS TWICE", "WHY HASN'T MY CARD BEEN DELIVERED"]

# %%
print(cluster_assignment)

# %% [markdown]
# ## Clustering with all-MiniLM embeddings

# %%
embedder_1 = SentenceTransformer('all-MiniLM-L6-v2')
corpus_embeddings_1 = embedder_1.encode(data)

# Perform K-Means Clustering
num_clusters = 6
clustering_model_1 = KMeans(n_clusters=num_clusters)
clustering_model_1.fit(corpus_embeddings_1) # Fit the embedding with kmeans clustering.
cluster_assignment_1 = clustering_model_1.labels_ # Get the cluster id assigned to each news headline.

clustered_sentences_1 = [[] for i in range(num_clusters)]

for sentence_id, cluster_id in enumerate(cluster_assignment_1):
    clustered_sentences_1[cluster_id].append(data[sentence_id])
for i, cluster in enumerate(clustered_sentences_1):
    print("Cluster ", i+1)
    print(cluster)
    print("")
# Out:
# Cluster  1
# ['WHY DID I GET CHARGED FOR SOMETHING I BOUGHT ON LINE EVEN THOUGH IT WAS INTERNATIONAL I THOUGHT IT WOULD BE COVERED', 'WHY WAS MY PAYMENT REVERSED', 'A TRANSACTION IS REPEATED SEVERAL TIMES ON MY ACCOUNT', 'CAN YOU PLEASE CHECK IF I WAS CHARGED TWICE', 'PLEASE CHECK PAYMENTS ON MY CART THERE IS A DUPLICATE AND I ONLY BOUGHT IT ONCE', 'I GOT DOUBLE CHARGED FOR A PAYMENT SO HOW DO I FIX THAT', 'I WAS WONDERING HOW I COULD HAVE TWO CHARGES FOR THE SAME ITEM HAPPEN MORE THAN ONCE IN A SEVEN DAY PERIOD IS THERE ANYWAY I COULD GET THIS CORRECTED A S A P', 'I SEE WHAT LOOKS LIKE DUPLICATE CHARGES ON ACCOUNT', 'IT APPEARS THAT I AM BEING DOUBLE CHARGED FOR SOME ITEMS THAT I HAVE PURCHASED THIS PAST WEEK PLEASE REVIEW AND CORRECT', 'WHY AM I BEING CHARGED TWICE', 'I WOULD LIKE TO KNOW WHY I WAS CHARGED TWICE FOR MY PURCHASE', "I'VE BEEN CHARGED MORE THAN ONCE FOR THE SAME TRANSACTION", 'THERE IS MORE THAN ONE OF THE SAME TRANSACTION ON MY ACCOUNT', "I DIDN'T BUY THIS TWICE", 'IT LOOKS LIKE THIS WEEK I WAS DOUBLE CHARGED FOR A COUPLE THINGS IS THERE ANY WAY THAT YOU CAN LOOK INTO THIS FOR ME AND RETURN THE DOUBLE CHARGED ITEMS BACK TO MY CART', 'I HAVE A DUPLICATE PAYMENT SHOWING', 'I HAVE A DUPLICATE PAYMENT SHOWING UP ON THE EP HOW DO I STOP MYSELF BEING CHARGED FOR THE THING TWICE', 'HELLO I CHECKED MY TRANSACTIONS AND SAW I WAS DOUBLE CHARGED ON MY CARD FOR A RESTAURANT VISIT I WOULD LIKE TO GET MY MONEY BACK', 'WHY WAS I JHULD TWICE FOR THE SAME THING', 'I THINK SOMETHING MAY HAVE HAPPENED THAT CAUSED A CHARGE TO SHOW UP TWICE', 'TRANSACTIONS ON MY CARRD LOOK REALLY WEIRD IAVE BEEN CHARGED TWICE FOR A COUPLE THINGS THIS WEEK PLEASE CHECK THIS IN RETURN THE DOUBLE CHARGED ONES', 'WHY AM I BEING CHARGED TWICE FOR OW A RESTAURANT', 'IHAVE JUST COME BACK FROM AN EATING HOLIDAY IN THE OU ESSAY AND CANADA AND HAVE SO MANY PENDING AND DUPLICATED TRANSACTIONS ON MY ACCOUNT I THINK THERE IS SOMETHING WRONG CAN YOU LOOK INTO IT PLEASE', 'WHAT ARE MY REMEDIES IF I THINK I WAS CHARGED TWICE FOR THE SAME EXPENSE', 'I HAVE A TRANSACTION THAT SHOWS SEVERAL TIMES', 'I NOTICED AFTER LOOKING OVER MY TRANSACTIONS THAT I HAVE BEEN CHARGED TWICE FROM AN EARLIER RESTAURANT VISIT THIS WEEK IS IT POSSIBLE THAT ONE OF THESE CAN BE REMOVED SO I GET THE MONEY BACK FOR THE ONE THAT IS NOT ACCURATE', 'WHY HAVE I BEEN CHARGED TWICE FOR THE SAME TRANSACTION', 'WHY IS THERE MORE THAN ONE CHARGE ON MY CART I ONLY PAID FOR ONE NOT TWICE HOW CAN I FIX THIS', 'I WAS DOUBLE CHARGED', 'I RECENTLY GOT CHARGED TWICE FROM A RESTAURANT THAN I WAS AT THIS WEEK AND I WOULD LIKE FOR ONE OF THOSE PAYMENTS TO BE REMOVED FROM MY ACCOUNT', 'I HAVE MULTIPLED CHARGES ON THE SAME TRANSACTION', 'MY RECEIPT SHOWS AN EXTRA CHARGE ON MY TRANSFER WHY IS THIS', "I WAS CHARGED FOR SOMETHING I DIDN'T EXPECT"]
#
# Cluster  2
# ['MY SALARY IS RECEIVED IN THE FORM OF G B P DO I NEED TO DO ANYTHING SPECIFIC TO CONFIGURE THIS', 'I RECEIVED MY SALARY IN G B P HOW DO I CHANGE THIS TO MY CURRENCY', 'WILL SALARY BE RECEIVED THROUGH THIS', 'CAN I USE THIS TO RECEIVE MY SALARY', 'IS G B P A SUPPORTED CURRENCY', 'CAN I GET MY SALARY THROUGH THIS', 'IS MY SALARY ELIGIBLE FOR THIS', 'DO I NEED TO ESTABLISH I AM PAID IN G B P BEFORE A TRANSFER', 'MY SALARY IS IN G B P HOW CAN I NOTE THIS IN THE AP', 'I GET PAID IN G B P SHOULD I CONFIGURE THIS AND IF SO WHERE', 'CAN I DIRECTLY TRANSFER MY SALARY ONTO HERE', 'IS THERE A PROBLEM WITH RECEIVING MY SALARY IN G B P', 'HOW DO I GET MY SALARY IN THE ACCOUNT', 'CAN I RECEIVE MY SALARY IN OCCURRENCY OTHER THAN WHAT IT IS DEPOSITED IN', 'HOW CAN I GET PAID IN A DIFFERENT CURRENCY', 'CAN I GET MY PAYCHECK THROUGH HERE', 'CAN I TRANSFER MY SALARY OF ITS IN A DIFFERENT CURRENCY']
#
# Cluster  3
# ['I NEED TO CHANGE MY PIN', 'I NEED A NEW PIN HOW DO I GO ABOUT THAT', 'DO CASH MACHINES LET ME CHANGE MY PIN', 'WHAT KIND OF CASH MACHINES WOULD ALLOW ME TO CHANGE MY PIN', "I DESPERATELY NEED TO CHANGE MY PIN BUT I'M OVERSEEZ ON VACATION RIGHT NOW HOW CAN I DO THIS", 'MY NEW PIN NEEDS TO BE SET', 'IN WHAT AH T M CAN I CHANGE MY PIN', 'I AM TRAVELLING FOR TWO MORE WEEKS BUT REALLY NEED TO CHANGE MY PINA ES APING WHAT DO I DO', 'IF I AM OVERSEAS HOW DO I CHANGE MY PIN', 'PLEASE TELL ME WHICH CASH MACHINES WILL ALLOW ME TO CHANGE MY PIN', 'CAN I CHANGE MY PIN AT THE AT M', 'HOW CAN I TELL WHERE MY FUNS CAME FROM', 'HOW CAN I CHECK THE SOURCE OF FUNS', 'HELP ME CHECK WEAR THE FUNS CAME FROM', 'HOW CAN I GET MY CART OUT OF THE DAMAT M']
#
# Cluster  4
# ['WHAT IS THE TRACKING NUMBER FOR MY CART THAT WAS MAILED', 'HOW DO I TRACK MY CARD', "I'M STARTING TO THINK MY CARD IS LOST BECAUSE IT STILL HASN'T ARRIVED CAN YOU HELP", 'MY CARD HAS NOT ARRIVED YET', 'STILL WAITING ON MY NEW CARD', 'MAY I RECEIVE A DIFFERENT CARD PEN', 'THERE MUST BE AN ISSUE WHY HAS MY CARD BEEN CANCELLED', 'WHAT DO I DO IF IT SAYS MY CARD PAYMENT HAS BEEN KENCELLED', 'WHY WAS MY CARD PAYMENT KENCELLED', 'I THINK MY CARD PAYMENT HAS BEEN STOPPED', 'WHY HAS MY CARD PAYMENT BEEN CANSELLED', 'MY CARD IS BEING DECLINED FOR A PURCHASE I BOUGHT ITEMS BEFORE AND THE CARD WORKED DO YOU KNOW WHAT THE PROBLEM IS', 'I HAVE NOT RECEIVED MY CARD', 'MY CARD PAYMENT WAS CANCELLED', 'I DID NOT GET MY CARD YET IS IT LOST', 'MY CARD WAS TAKEN BY THE EIGH T M', "THE EIGHT M WON'T GIVE MY CARD BACK", 'I HAVE A PROBLEM THE A T M STOLE MY CARD', 'WHAT DO I DO IF AN A T M STOLE MY CARD', 'WHEN WILL I GET MY CARD', 'I HAVE BEEN WAITING LONGER THAN EXPECTED FOR MY BANK CARD COULD YOU PROVIDE INFORMATION ON WHEN IT WILL ARRIVE', 'HOW LONG SHOULD MY NEW CARD TAKE TO ARRIVE', 'I ORDERED A CARD BUT IT HAS NOT ARRIVED HELP PLEASE', "I ORDERED MY CARD TWO WEEKS AGO AND IT STILL ISN'T HERE WHAT DO I DO", 'I STILL HAVE NOT RECEIVED MY NEW CARD I ORDERED OVER A WEEK AGO', 'WHERE IS THE TRACKING NUMBER FOR THE CARD YOU SENT ME', 'DOES THE CARD YOU SENT HAVE A WAY TO TRACK TO IT', 'I AM STILL WAITING FOR MY CART AFTER ONE WEEK IS THIS O KU', 'I WANT TO TRACK THE CARD YOU SCENT', 'DO YOU KNOW IF THERE IS A TRACKING NUMBER FOR THE NEW CARD YOU SENT ME', "I WAS EXPECTING MY NEW CARDAN AND WONDERING WHY I HAVEN'T RECEIVED IT YET", "I ORDERED A CARD AND I STILL HAVEN'T RECEIVED IT IT'S BEEN TWO WEEKS WHAT CAN I DO", 'HOW DO I KNOW WHEN MY CARD WILL ARRIVE', 'STILL WAITING ON THAT CART', 'HOW DO I LOCATE MY CARD', "MY CART HASN'T ARRIVED YET", "MY CARD STILL HASN'T ARRIVED AFTER TWO WEEKS IS IT LOST", 'HOW LONG DOES A CARD DELIVERY TAKE', "I'M STILL WAITING FOR DELIVERY OF MY NEW CARD WHY IS IT TAKING SO LONG", "I'M STILL WAITING ON MY CARD TO BE DELIVERED", "I'VE BEEN WAITING LONGER THAN EXPECTED FOR MY CARD", 'IS IT NORMAL TO HAVE TO WAIT OVER A WEEK FOR MY NEW CART', "WHY HASN'T MY CARD BEEN DELIVERED", "I STILL DON'T HAVE MY CART AFTER TWO WEEKS WHAT SHOULD I DO", 'STATUS OF THE CARTD I ORDERED', 'CAN THIS BE USED TO RECEIVE MY CELLERY', 'IS THERE A WAY TO KNOW WHEN MY CARD WILL ARRIVE']
#
# Cluster  5
# ["I'M NOT PAYING THIS TRANSFER FEE", 'I THOUGHT TRANSFERS WERE FREE WHY WAS I CHARGE TO FEE', 'WHAT IS THE TRANSFER F E CHARGE', "MY TRANSFER TO BENEFICIARY DIDN'T GO THROUGH", "WHY CAN'T I TRANSFER TO A BENEFICIARY", 'WHY DID I RECEIVE AN ERROR MESSAGE SAYING THAT MY TRANSFER WAS NOT POSSIBLE', "I'VE TROD NUMEROUS TIMES TO SUBMIT A TRANSFER OF FUNDS WHY ISN'T IT GOING THROUGH", "I TRIED TO TRANSFER MONEY BUT IT SAID IT WASN'T POSSIBLE I'VE DONE THIS BEFORE AND IT WORKED WHY ISN'T IT WORKING NOW", "I COULDN'T DO A TRANSFER TO AN ACCOUNT", 'I WAS UNABLE TO MAKE A TRANSFER TO ANOTHER ACCOUNT', "WHY ISN'T MY TRANSFER GOING THROUGH I GET A MESSAGE SAYING IT'S NOT POSSIBLE I'VE HAD NO ISSUES IN THE PAST", "WHY ISN'T MY ACCOUNT ALLOWING TRANSFERS", 'I HAD A TRANSFER BLOCKED', "WHY ISN'T MY TRANSFER NOT GOING THROUGH I KEEP GETTING AN ARROR MESSAGE", 'WHY DID I GET A MESSAGE SAYING THAT MY TRANSFER IS NOT POSSIBLE I HAVE DONE THIS BEFORE NO PROBLEM PLEASE FIX', 'WHEN WILL I RECEIVE A YU S TRANSFER', 'HOW LONG DOES IT TAKE FOR A TRANSFER', 'WHAT IS THE NUMBER OF DAYS I HAVE TO WAIT FOR MY EUROPE TRANSFER', 'IF I STARTED THE BANK TRANSFER FROM EUROPE HOW LONG WILL THE PROCESS TAKE TO COMPLETE', 'WHEN SHOULD I EXPECT TO SEE MY TRANSFER HIT MY ACCOUNT', 'HOW LONG IS THE WAIT FOR A UAS TRANSFER', 'THERE WAS AN EXTRA CHARGE WHEN I MADE A TRANSFER', 'I GOT TWO TRANSFER FEAS AND I THOUGHT TRANSFERS WERE FREE', 'I SENT OUT MONEY BUT WAS CHARGED EXTRA FOR TRANSFERRING WHY', 'WHEN I MADE A TRANSFER THERE WAS A FEET WHY', 'WHAT IS THE MAXIMUM I CAN TRANSFER BEFORE I IN CURFES', 'I WAS CHARGED MORE WHEN I TRANSFERRED', 'DO CHARGE FEES FOR YOUR TRANSFERS', 'WHY WAS A CHARGE JUST FOR TRANSFERRING', "I NEED SOME ONE TO ALERT ME AS TO WHAT'S GOING ON I HAD TRANSFERRED AN AMOUNT BUT THE RECEIVER IS SAYING THAT THE AMOUNT IS SOMEWHAT LESS THAN WHAT I SENT OVER I NOW HAVE TO MAKE ANOTHER TRANSFER TO MAKE UP THE DIFFERENCE", 'I HAD TO PAY IN ORDER TO DO A TRANSFER']
#
# Cluster  6
# ["I RECENTLY GOT A NEW PLACE WHILE I'M STAYING ABROAD AND HAVE BEEN USING THIS ACCOUNT TO MANAGE PAYMENTS BUT SUDDENLY I AM SEEING FEES INCREASE WHERE ARE THESE ADDITIONAL FEES COMING FROM", 'I PURCHASED SOME MAKE UP THROUGH A SIGHT IN CHINA AND I WAS UNDER THE IMPRESSION THAT WHEN I MAY TRANSFERS THERE IS NO FEE WHY AM I SEEING THIS FENOW I AM NOT HAPPY ABOUT THIS AT ALL', "I HAVE A CRIPTO CURRENCY EXCHANGE THAT WON'T GO THROUGH PLEASE HELP ME PROCESS IT", "WHAT'S THE DEAL WITH NO CRYPTO CURRENCY ON YOUR RAP", "I WANT TO BUY CRIPTO CURRENCY BUT YOUR AP DOESN'T LET ME WHY", 'IS THEIR TRACKING INFO AVAILABLE', 'WHAT HAPPENS TO THE FUNS IF A MERCHANT REFUSES THE PAYMENT', 'HOW LONG UNTIL THE MONEY IS IN MY ACCOUNT', 'HOW LONG DOES IT TAKE FOR FUNS TO COME THROUGH THE US TO MY ACCOUNT', 'WHY DOES MY MONEY COME FROM', 'I HAVE TO VERIFY THE SOURCE OF MY FUNDS', 'CAN I VERIFY THE SOURCE OF MY FUNDS', 'CAN MY FRIENDS SEND ME MONEY', 'WHAT DIFFERENT WAYS ARE THERE FOR SOME ONE TO SEND ME MONEY', 'HOW DO I DEPOSIT MY PAY CHECK TO THIS ACCOUNT', 'HOW CAN SOME ONE SEND ME MONEY', 'IS IT POSSIBLE TO DEPOSIT MONEY IN G B P']

# %%
print(clustered_sentences_1[0][0])
# Out:
# WHY DID I GET CHARGED FOR SOMETHING I BOUGHT ON LINE EVEN THOUGH IT WAS INTERNATIONAL I THOUGHT IT WOULD BE COVERED

# %%
cluster_assignment_1[0]
# Out:
# 3

# %% [markdown]
# ## Flask API

# %%
from flask import Flask, request, redirect, url_for, flash, jsonify
import pickle as p
import json
import requests


app = Flask(__name__)


@app.route('/api/', methods=['POST'])
def makecalc():
    data = request.get_json()
    prediction = np.array2string(model.predict(data))

    return jsonify(prediction)

if __name__ == '__main__':
    modelfile = 'models/final_prediction.pickle'
    model = p.load(open(modelfile, 'rb'))
    app.run(debug=True, host='0.0.0.0')
    
url = 'http://0.0.0.0:4000/api/'

data = [[14.34, 1.68, 2.7, 25.0, 98.0, 2.8, 1.31, 0.53, 2.7, 13.0, 0.57, 1.96, 660.0]]
j_data = json.dumps(data)
headers = {'content-type': 'application/json', 'Accept-Charset': 'UTF-8'}
r = requests.post(url, data=j_data, headers=headers)
print(r, r.text)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [283], in <cell line: 16>()
#      16 if __name__ == '__main__':
#      17     modelfile = 'models/final_prediction.pickle'
# ---> 18     model = p.load(open(modelfile, 'rb'))
#      19     app.run(debug=True, host='0.0.0.0')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'models/final_prediction.pickle'
